# %%
import pints
import pints.toy as toy
import pints.plot

import emupints
import emupints.plot as emuplt
import emupints.utils as emutils
import emupints.metrics as emumet

from emupints.models import create_small_model, create_average_model, create_large_model

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras

import string

# %% [markdown]
# # Problem parameters

# %%
# Load problem from predefined ones
model = emupints.Problems.SIRModel
problem = emupints.Problems.load_problem(model)

problem['values'][:5]
# Out:
# array([[-0.48000695,  0.27258255],
#        [ 1.27376996,  1.90382036],
#        [ 1.13864888, -3.38207659],
#        [ 0.4707283 ,  0.62770159],
#        [ 1.7259489 , -1.41829099]])

# %%
toy.HodgkinHuxleyIKModel().suggested_times()
# Out:
# array([0.00000e+00, 2.50000e-01, 5.00000e-01, ..., 1.19925e+03,
#        1.19950e+03, 1.19975e+03])

# %%
# take all the required variables from the problem
n_parameters = problem['n_parameters']
log_likelihood = problem['log_likelihood']
log_prior = problem['log_prior']
log_posterior = problem['log_posterior']
real_parameters = problem['parameters']
pints_problem = problem['problem']
bounds = problem['bounds']
index_to_param_name = problem['param_names']

# %% [markdown]
# # Apply CMA-ES

# %%
# CMA-es
score = pints.SumOfSquaresError(pints_problem)
x0 = bounds.sample(1)[0]

found_parameters, found_value = pints.optimise(
    score,
    x0,
    None,
    bounds,
    method=pints.CMAES
)
# Out:
# Minimising error measure
# using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 7
# Iter. Eval. Best      Time m:s
# 0     7      6008.769   0:00.1
# 1     14     4077.82    0:00.1
# 2     21     1079.623   0:00.1
# 3     28     1044.55    0:00.2
# 20    147    983.452    0:00.4
# 40    287    981.6582   0:00.8
# 60    427    981.6564   0:01.2
# 80    567    981.6564   0:01.5
# 100   707    981.6564   0:01.9
# 120   847    981.6564   0:02.3
# 140   987    981.6564   0:02.8
# 160   1127   981.6564   0:03.0
# 180   1267   981.6564   0:03.2
# 200   1407   981.6564   0:03.3
# 220   1547   981.6564   0:03.4
# 240   1687   981.6564   0:03.5
# 260   1827   981.6564   0:03.7
# 280   1967   981.6564   0:03.8
# 286   2002   981.6564   0:03.8
# Halting: No significant change for 200 iterations.

# %% [markdown]
# # Use found parameters to sample trianing data

# %%
# training size
# use bigger training size for NNs because speed stays the same
train_size = 2000
test_size = 400
sampling_std = 0.05 * found_parameters # take 0.05% around found parameters std

def normal_sampling(size, mean, std):
    return mean + np.random.randn(*size) * std

# create data for training and testing
# genera example using normal distribution around parametrs
train_X = normal_sampling((train_size, n_parameters), found_parameters, sampling_std)
train_y = np.apply_along_axis(log_likelihood, 1, train_X)

# if provide validation data to keras model also need to normalize it 
test_X = normal_sampling((test_size, n_parameters), found_parameters, sampling_std)
test_y = np.apply_along_axis(log_likelihood, 1, test_X)

# %% [markdown]
# # Create NN emulator

# %%
EPOCHS = 50
BATCH = 32
validation_split = 0.2

# %%
# how to scale data
# for input use standardisation, same as GPs
# for output scale linearly in range (-1, 1)
input_scaler = MinMaxScaler(feature_range=(-1, 1))
output_scaler = StandardScaler()

# %%
emu = emupints.NNEmulator(log_likelihood, 
                          train_X,
                          train_y,
                          model_size='small',
                          input_scaler=input_scaler, 
                          output_scaler=output_scaler
                         )

# %%
# print summary of the model
emu.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 16,897
# Trainable params: 16,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
# store best
mc_callback = keras.callbacks.ModelCheckpoint("model_{epoch:02d}.h5", 
                                              save_weights_only=True,  
                                             )

# %%
# store the results during training
val_umae = []

# Callback to calculate unormalized mae
class UnormalizedMAE(keras.callbacks.Callback):

    def on_epoch_end(self, batch, logs={}):
        X_val, y_val = self.validation_data[0], self.validation_data[1]
        
        y_val_predict = np.asarray(self.model.predict(X_val))

        # unormalize predictions
        y_val = output_scaler.inverse_transform(y_val)
        y_val_predict = output_scaler.inverse_transform(y_val_predict)

        # calculate mae
        mae_val = np.mean(np.abs(y_val - y_val_predict))

        # store results
        val_umae.append(mae_val)

        return

# %%
#optimizer = tf.train.RMSPropOptimizer(learning_rate)
emu.set_parameters(
    loss='mse',
    optimizer='adam',
    metrics=['mae'] # mean absolute error
)

# %%
history = emu.fit(epochs=EPOCHS,
                  batch_size=BATCH,
                  validation_split=0.2,
                  callbacks=[mc_callback,UnormalizedMAE()],
                 )
# Out:
# Train on 1600 samples, validate on 400 samples
# Epoch 1/50
# 1600/1600 [==============================] - 0s 252us/step - loss: 2.1749 - mean_absolute_error: 0.6594 - val_loss: 1.4610 - val_mean_absolute_error: 0.5163
# Epoch 2/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 1.1113 - mean_absolute_error: 0.3595 - val_loss: 0.7494 - val_mean_absolute_error: 0.2249
# Epoch 3/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.6370 - mean_absolute_error: 0.2048 - val_loss: 0.5098 - val_mean_absolute_error: 0.1887
# Epoch 4/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.4568 - mean_absolute_error: 0.1734 - val_loss: 0.3891 - val_mean_absolute_error: 0.1675
# Epoch 5/50
# 1600/1600 [==============================] - 0s 45us/step - loss: 0.3629 - mean_absolute_error: 0.1709 - val_loss: 0.3242 - val_mean_absolute_error: 0.1662
# Epoch 6/50
# 1600/1600 [==============================] - 0s 46us/step - loss: 0.3100 - mean_absolute_error: 0.1685 - val_loss: 0.2857 - val_mean_absolute_error: 0.1668
# Epoch 7/50
# 1600/1600 [==============================] - 0s 62us/step - loss: 0.2711 - mean_absolute_error: 0.1592 - val_loss: 0.2526 - val_mean_absolute_error: 0.1593
# Epoch 8/50
# 1600/1600 [==============================] - 0s 66us/step - loss: 0.2525 - mean_absolute_error: 0.1636 - val_loss: 0.2336 - val_mean_absolute_error: 0.1608
# Epoch 9/50
# 1600/1600 [==============================] - 0s 69us/step - loss: 0.2330 - mean_absolute_error: 0.1577 - val_loss: 0.2283 - val_mean_absolute_error: 0.1655
# Epoch 10/50
# 1600/1600 [==============================] - 0s 54us/step - loss: 0.2209 - mean_absolute_error: 0.1558 - val_loss: 0.2080 - val_mean_absolute_error: 0.1563
# Epoch 11/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.2202 - mean_absolute_error: 0.1722 - val_loss: 0.2165 - val_mean_absolute_error: 0.1949
# Epoch 12/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.2052 - mean_absolute_error: 0.1591 - val_loss: 0.1940 - val_mean_absolute_error: 0.1537
# Epoch 13/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.1966 - mean_absolute_error: 0.1581 - val_loss: 0.1862 - val_mean_absolute_error: 0.1548
# Epoch 14/50
# 1600/1600 [==============================] - 0s 43us/step - loss: 0.1908 - mean_absolute_error: 0.1526 - val_loss: 0.1823 - val_mean_absolute_error: 0.1539
# Epoch 15/50
# 1600/1600 [==============================] - 0s 45us/step - loss: 0.1846 - mean_absolute_error: 0.1538 - val_loss: 0.1905 - val_mean_absolute_error: 0.1651
# Epoch 16/50
# 1600/1600 [==============================] - 0s 44us/step - loss: 0.1872 - mean_absolute_error: 0.1623 - val_loss: 0.2069 - val_mean_absolute_error: 0.1826
# Epoch 17/50
# 1600/1600 [==============================] - 0s 45us/step - loss: 0.1832 - mean_absolute_error: 0.1581 - val_loss: 0.1743 - val_mean_absolute_error: 0.1542
# Epoch 18/50
# 1600/1600 [==============================] - 0s 49us/step - loss: 0.1779 - mean_absolute_error: 0.1530 - val_loss: 0.1799 - val_mean_absolute_error: 0.1642
# Epoch 19/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.1836 - mean_absolute_error: 0.1681 - val_loss: 0.1877 - val_mean_absolute_error: 0.1801
# Epoch 20/50
# 1600/1600 [==============================] - 0s 41us/step - loss: 0.1797 - mean_absolute_error: 0.1646 - val_loss: 0.1704 - val_mean_absolute_error: 0.1615
# Epoch 21/50
# 1600/1600 [==============================] - 0s 44us/step - loss: 0.1687 - mean_absolute_error: 0.1506 - val_loss: 0.1632 - val_mean_absolute_error: 0.1517
# Epoch 22/50
# 1600/1600 [==============================] - 0s 72us/step - loss: 0.1653 - mean_absolute_error: 0.1469 - val_loss: 0.1623 - val_mean_absolute_error: 0.1487
# Epoch 23/50
# 1600/1600 [==============================] - 0s 74us/step - loss: 0.1672 - mean_absolute_error: 0.1491 - val_loss: 0.1655 - val_mean_absolute_error: 0.1542
# Epoch 24/50
# 1600/1600 [==============================] - 0s 73us/step - loss: 0.1682 - mean_absolute_error: 0.1554 - val_loss: 0.1867 - val_mean_absolute_error: 0.2046
# Epoch 25/50
# 1600/1600 [==============================] - 0s 51us/step - loss: 0.1711 - mean_absolute_error: 0.1668 - val_loss: 0.1665 - val_mean_absolute_error: 0.1565
# Epoch 26/50
# 1600/1600 [==============================] - 0s 74us/step - loss: 0.1613 - mean_absolute_error: 0.1525 - val_loss: 0.1651 - val_mean_absolute_error: 0.1648
# Epoch 27/50
# 1600/1600 [==============================] - 0s 56us/step - loss: 0.1596 - mean_absolute_error: 0.1464 - val_loss: 0.1557 - val_mean_absolute_error: 0.1517
# Epoch 28/50
# 1600/1600 [==============================] - 0s 83us/step - loss: 0.1584 - mean_absolute_error: 0.1468 - val_loss: 0.1534 - val_mean_absolute_error: 0.1515
# Epoch 29/50
# 1600/1600 [==============================] - 0s 72us/step - loss: 0.1557 - mean_absolute_error: 0.1450 - val_loss: 0.1569 - val_mean_absolute_error: 0.1544
# Epoch 30/50
# 1600/1600 [==============================] - 0s 62us/step - loss: 0.1578 - mean_absolute_error: 0.1508 - val_loss: 0.1495 - val_mean_absolute_error: 0.1486
# Epoch 31/50
# 1600/1600 [==============================] - 0s 82us/step - loss: 0.1537 - mean_absolute_error: 0.1480 - val_loss: 0.1493 - val_mean_absolute_error: 0.1498
# Epoch 32/50
# 1600/1600 [==============================] - 0s 82us/step - loss: 0.1541 - mean_absolute_error: 0.1503 - val_loss: 0.1483 - val_mean_absolute_error: 0.1558
# Epoch 33/50
# 1600/1600 [==============================] - 0s 56us/step - loss: 0.1524 - mean_absolute_error: 0.1486 - val_loss: 0.1481 - val_mean_absolute_error: 0.1518
# Epoch 34/50
# 1600/1600 [==============================] - 0s 90us/step - loss: 0.1543 - mean_absolute_error: 0.1569 - val_loss: 0.1526 - val_mean_absolute_error: 0.1563
# Epoch 35/50
# 1600/1600 [==============================] - 0s 76us/step - loss: 0.1538 - mean_absolute_error: 0.1552 - val_loss: 0.1507 - val_mean_absolute_error: 0.1664
# Epoch 36/50
# 1600/1600 [==============================] - 0s 45us/step - loss: 0.1486 - mean_absolute_error: 0.1520 - val_loss: 0.1644 - val_mean_absolute_error: 0.1818
# Epoch 37/50
# 1600/1600 [==============================] - 0s 43us/step - loss: 0.1493 - mean_absolute_error: 0.1523 - val_loss: 0.1433 - val_mean_absolute_error: 0.1475
# Epoch 38/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.1471 - mean_absolute_error: 0.1485 - val_loss: 0.1455 - val_mean_absolute_error: 0.1624
# Epoch 39/50
# 1600/1600 [==============================] - 0s 43us/step - loss: 0.1437 - mean_absolute_error: 0.1447 - val_loss: 0.1446 - val_mean_absolute_error: 0.1635
# Epoch 40/50
# 1600/1600 [==============================] - 0s 56us/step - loss: 0.1443 - mean_absolute_error: 0.1486 - val_loss: 0.1436 - val_mean_absolute_error: 0.1546
# Epoch 41/50
# 1600/1600 [==============================] - 0s 68us/step - loss: 0.1441 - mean_absolute_error: 0.1511 - val_loss: 0.1460 - val_mean_absolute_error: 0.1557
# Epoch 42/50
# 1600/1600 [==============================] - 0s 65us/step - loss: 0.1545 - mean_absolute_error: 0.1588 - val_loss: 0.1415 - val_mean_absolute_error: 0.1540
# Epoch 43/50
# 1600/1600 [==============================] - 0s 70us/step - loss: 0.1504 - mean_absolute_error: 0.1587 - val_loss: 0.1488 - val_mean_absolute_error: 0.1620
# Epoch 44/50
# 1600/1600 [==============================] - 0s 65us/step - loss: 0.1492 - mean_absolute_error: 0.1578 - val_loss: 0.1455 - val_mean_absolute_error: 0.1638
# Epoch 45/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.1438 - mean_absolute_error: 0.1514 - val_loss: 0.1376 - val_mean_absolute_error: 0.1504
# Epoch 46/50
# 1600/1600 [==============================] - 0s 41us/step - loss: 0.1449 - mean_absolute_error: 0.1564 - val_loss: 0.1388 - val_mean_absolute_error: 0.1541
# Epoch 47/50
# 1600/1600 [==============================] - 0s 44us/step - loss: 0.1468 - mean_absolute_error: 0.1609 - val_loss: 0.1465 - val_mean_absolute_error: 0.1678
# Epoch 48/50
# 1600/1600 [==============================] - 0s 42us/step - loss: 0.1380 - mean_absolute_error: 0.1460 - val_loss: 0.1384 - val_mean_absolute_error: 0.1585
# Epoch 49/50
# 1600/1600 [==============================] - 0s 41us/step - loss: 0.1373 - mean_absolute_error: 0.1489 - val_loss: 0.1339 - val_mean_absolute_error: 0.1604
# Epoch 50/50
# 1600/1600 [==============================] - 0s 43us/step - loss: 0.1374 - mean_absolute_error: 0.1462 - val_loss: 0.1346 - val_mean_absolute_error: 0.1513

# %%
best_model_idx = np.argmin(val_umae)
emu._model.load_weights("model_{:02d}.h5".format(best_model_idx))

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Mean Abs Error')
plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
       label='Train mae')
plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
       label = 'Val mae')
plt.legend()

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(history.epoch, np.array(history.history['loss']),
       label='Train Loss')
plt.plot(history.epoch, np.array(history.history['val_loss']),
       label = 'Val loss')
plt.legend()

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Unormalized mae')
plt.plot(history.epoch, val_umae)

# %% [markdown]
# # Likelihood metrics

# %%
emu_time = %timeit -r 50 -o emu(real_parameters)
print("Emulator prediction time (micro-seconds): {:5f}".format(emu_time.average * 1000000))
# Out:
# 545 µs ± 117 µs per loop (mean ± std. dev. of 50 runs, 1000 loops each)
# Emulator prediction time (micro-seconds): 544.680893

# %%
likelihood_time = %timeit -r 50 -o log_likelihood(real_parameters)
print("Likelihood prediction time (micro-seconds): {:5f}".format(likelihood_time.average * 1000000))
# Out:
# 595 µs ± 19.5 µs per loop (mean ± std. dev. of 50 runs, 1000 loops each)
# Likelihood prediction time (micro-seconds): 594.829971

# %%
pred_y = np.apply_along_axis(emu, 1, test_X)
print("Mean absolute error (mae): {:.5f}".format(emumet.mae(test_y, pred_y)))
# Out:
# Mean absolute error (mae): 391.53621

# %%
print("Mean percentage error (mape): {:.5f}".format(emumet.mape(test_y, pred_y) * 100))
# Out:
# Mean percentage error (mape): 36.55887

# %% [markdown]
# # Comparing MCMC run times

# %%
mcmc_method = pints.AdaptiveCovarianceMCMC

# MCMC parameters
num_chains = 3
max_iters = 10000

# %%
# Create a posterior log-likelihood (log(likelihood * prior))
emu_log_posterior = pints.LogPosterior(emu, log_prior)

# %%
xs = [
    found_parameters,
    found_parameters,
    found_parameters,
]
xs
# Out:
# [array([2.73628104e-02, 2.77894791e-01, 3.72607581e+01]),
#  array([2.73628104e-02, 2.77894791e-01, 3.72607581e+01]),
#  array([2.73628104e-02, 2.77894791e-01, 3.72607581e+01])]

# %%
emu_mcmc = pints.MCMCSampling(emu_log_posterior,
                              num_chains,
                              xs,
                              method = mcmc_method,
                             )
emu_mcmc.set_log_to_screen(False)
print('Running...')
emu_chains = emu_mcmc.run()
print('Done!')
# Out:
# Running...
# Done!

# %%
real_mcmc = pints.MCMCSampling(log_posterior, 
                               num_chains, 
                               xs, 
                               method = mcmc_method,
                               )
real_mcmc.set_max_iterations(max_iters)
real_mcmc.set_log_to_screen(False)
# Run!
print('Running...')
real_chains = real_mcmc.run()
print('Done!')
# Out:
# Running...
# Done!

# %%
pints.plot.trace(emu_chains)
plt.show()

# %%
pints.plot.trace(real_chains)
plt.show()

# %% [markdown]
# # MCMC metrics

# %%
print('Emulator R-hat:')
print(pints.rhat_all_params(emu_chains))
# Out:
# Emulator R-hat:
# [1.0022392736180377, 0.9999817836867422, 1.0009552763530687]

# %%
print('Real R-hat:')
print(pints.rhat_all_params(real_chains))
# Out:
# Real R-hat:
# [1.0090636006641192, 1.00398631148281, 1.0000096956771882]

# %%
# percentage
chain = real_chains[0]

chain_mape = emumet.chain_mape(chain, emu, log_likelihood)
print("Chain mean absolute percentage error: {:.5f}".format(chain_mape * 100))
# Out:
# Chain mean absolute percentage error: 0.62033

# %%
emu_mcmc_time = %timeit -o emu_mcmc.run()
print("Emulator MCMC time: {:.5f}".format(emu_mcmc_time.average))
# Out:
# 26.7 s ± 4.21 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Emulator MCMC time: 26.74195

# %%
real_mcmc_time = %timeit -o real_mcmc.run()
print("MCMC time: {:.5f}".format(real_mcmc_time.average))
# Out:
# 26.5 s ± 4.37 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
# MCMC time: 26.49506

# %%
emu_parameters, emu_parameters_std = emumet.estimate_parameters(emu_chains)
print("Emulator estimated parameters: ", emu_parameters)
print("Emulator parametet std: ", emu_parameters_std)
# Out:
# Emulator estimated parameters:  [2.57012634e-02 2.90464748e-01 3.89744687e+01]
# Emulator parametet std:  [3.18015860e-05 2.20120178e-04 2.79997462e-02]

# %%
real_parameters, real_parameters_std = emumet.estimate_parameters(real_chains)
print("Estimated parameters: ", real_parameters)
print("parametet std: ", real_parameters_std)
# Out:
# Estimated parameters:  [2.62611616e-02 2.84835966e-01 3.84468219e+01]
# parametet std:  [5.46079238e-05 2.10113045e-04 3.95375605e-02]

# %% [markdown]
# # Plotting emulator surfaces around parameters

# %%
# use smaller bounds to get an idea of the surface around real parameters
min_bounds = np.min(chain, axis = 0)
max_bounds = np.max(chain, axis = 0)
bounds = pints.RectangularBoundaries(min_bounds, max_bounds)

# %%
bounds

# %%
# plot surfaces
if n_parameters >= 3:
    fixed_parameters = emutils.fix_parameters(bounds)
    
    fig, ax = emuplt.plot_fixed_param_grid(
        emu,
        fixed_parameters,
        bounds,
        shape = (n_parameters, n_parameters - 1),
        contour = False,
        index_to_param_name=index_to_param_name,
        additional_log_likelihoods = [log_likelihood]
    )

    plt.show(fig)
    
# for row i we have parameter i fixed and some other parameter j, depending on the column, j != i

# %%
print(bounds.lower())
print(bounds.upper())
# Out:
# [2.58571309e-02 2.77894791e-01 3.72607581e+01]
# [2.73628104e-02 2.91626970e-01 3.89991859e+01]

# %%
fig, ax = emuplt.plot_surface_fixed_param(
    emu,
    bounds,
    fixed = [(1, 0.29)],
    index_to_param_name=index_to_param_name,
    contour=False,
    precision=2,
    additional_log_likelihoods=[log_likelihood],
)

# %%
ax.view_init(40, 60 + 90 * 3)
fig.set_size_inches(10.5, 6)
fig
