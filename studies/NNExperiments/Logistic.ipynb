# %%
import pints
import pints.toy as toy
import pints.plot

import emupints
import emupints.plot as emuplt
import emupints.utils as emutils
import emupints.metrics as emumet

from emupints.models import create_small_model, create_average_model, create_large_model

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras

import string

# %% [markdown]
# # Problem parameters

# %%
# Load problem from predefined ones
model = emupints.Problems.LogisticModel
problem = emupints.Problems.load_problem(model)

problem['values'][:5]
# Out:
# array([-30.53050465,   0.21186883,  39.17322843, -24.63539339,
#        -20.65502217])

# %%
toy.HodgkinHuxleyIKModel().suggested_times()
# Out:
# array([0.00000e+00, 2.50000e-01, 5.00000e-01, ..., 1.19925e+03,
#        1.19950e+03, 1.19975e+03])

# %%
# take all the required variables from the problem
n_parameters = problem['n_parameters']
log_likelihood = problem['log_likelihood']
log_prior = problem['log_prior']
log_posterior = problem['log_posterior']
real_parameters = problem['parameters']
pints_problem = problem['problem']
bounds = problem['bounds']
index_to_param_name = problem['param_names']

# %% [markdown]
# # Apply CMA-ES

# %%
# CMA-es
score = pints.SumOfSquaresError(pints_problem)
x0 = bounds.sample(1)[0]

found_parameters, found_value = pints.optimise(
    score,
    x0,
    None,
    bounds,
    method=pints.CMAES
)
# Out:
# Minimising error measure
# using Covariance Matrix Adaptation Evolution Strategy (CMA-ES)
# Running in sequential mode.
# Population size: 6
# Iter. Eval. Best      Time m:s
# 0     6      512167.8   0:00.1
# 1     12     512167.8   0:00.1
# 2     18     511346.8   0:00.1
# 3     24     511342.4   0:00.1
# 20    126    510879     0:00.1
# 40    246    473774.9   0:00.1
# 60    366    120968.9   0:00.2
# 80    486    120574.6   0:00.2
# 100   606    120574.6   0:00.2
# 120   726    120574.6   0:00.2
# 140   846    120574.6   0:00.3
# 160   966    120574.6   0:00.3
# 180   1086   120574.6   0:00.3
# 200   1206   120574.6   0:00.4
# 220   1326   120574.6   0:00.4
# 240   1446   120574.6   0:00.4
# 260   1566   120574.6   0:00.5
# 280   1686   120574.6   0:00.5
# 300   1806   120574.6   0:00.5
# 320   1926   120574.6   0:00.6
# 340   2046   120574.6   0:00.6
# 360   2166   120574.6   0:00.6
# 380   2286   120574.6   0:00.6
# 400   2406   120574.6   0:00.7
# 420   2526   120574.6   0:00.7
# 440   2646   120574.6   0:00.7
# 460   2766   120574.6   0:00.7
# 480   2886   120574.6   0:00.7
# 500   3006   120574.6   0:00.8
# 504   3024   120574.6   0:00.8
# Halting: No significant change for 200 iterations.

# %% [markdown]
# # Use found parameters to sample trianing data

# %%
# training size
# use bigger training size for NNs because speed stays the same
train_size = 1000
test_size = 400
sampling_std = 0.05 * found_parameters # take 0.05% around found parameters std

def normal_sampling(size, mean, std):
    return mean + np.random.randn(*size) * std

# create data for training and testing
# genera example using normal distribution around parametrs
train_X = normal_sampling((train_size, n_parameters), found_parameters, sampling_std)
train_y = np.apply_along_axis(log_likelihood, 1, train_X)

# if provide validation data to keras model also need to normalize it 
test_X = normal_sampling((test_size, n_parameters), found_parameters, sampling_std)
test_y = np.apply_along_axis(log_likelihood, 1, test_X)

# %% [markdown]
# # Create NN emulator

# %%
EPOCHS = 50
BATCH = 16
validation_split = 0.2

# %%
# how to scale data
# for input use standardisation, same as GPs
# for output scale linearly in range (-1, 1)
input_scaler = MinMaxScaler(feature_range=(-1, 1))
output_scaler = StandardScaler()

# %%
emu = emupints.NNEmulator(log_likelihood, 
                          train_X,
                          train_y,
                          model_size='small',
                          input_scaler=input_scaler, 
                          output_scaler=output_scaler
                         )

# %%
# print summary of the model
emu.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                192
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 16,833
# Trainable params: 16,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
# store best
mc_callback = keras.callbacks.ModelCheckpoint("models/model_{epoch:02d}.h5", 
                                              save_weights_only=True,  
                                             )

# %%
# store the results during training
val_umae = []

# Callback to calculate unormalized mae
class UnormalizedMAE(keras.callbacks.Callback):

    def on_epoch_end(self, batch, logs={}):
        X_val, y_val = self.validation_data[0], self.validation_data[1]
        
        y_val_predict = np.asarray(self.model.predict(X_val))

        # unormalize predictions
        y_val = output_scaler.inverse_transform(y_val)
        y_val_predict = output_scaler.inverse_transform(y_val_predict)

        # calculate mae
        mae_val = np.mean(np.abs(y_val - y_val_predict))

        # store results
        val_umae.append(mae_val)

        return

# %%
#optimizer = tf.train.RMSPropOptimizer(learning_rate)
emu.set_parameters(
    loss='mse',
    optimizer='adam',
    metrics=['mae'] # mean absolute error
)

# %%
history = emu.fit(epochs=EPOCHS,
                  batch_size=BATCH,
                  validation_split=0.2,
                  callbacks=[mc_callback,UnormalizedMAE()],
                 )
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/50
# 800/800 [==============================] - 0s 492us/step - loss: 2.2057 - mean_absolute_error: 0.7083 - val_loss: 1.7564 - val_mean_absolute_error: 0.6783
# Epoch 2/50
# 800/800 [==============================] - 0s 133us/step - loss: 1.2860 - mean_absolute_error: 0.5148 - val_loss: 0.8326 - val_mean_absolute_error: 0.2855
# Epoch 3/50
# 800/800 [==============================] - 0s 137us/step - loss: 0.6466 - mean_absolute_error: 0.2028 - val_loss: 0.5461 - val_mean_absolute_error: 0.2046
# Epoch 4/50
# 800/800 [==============================] - 0s 134us/step - loss: 0.4561 - mean_absolute_error: 0.1460 - val_loss: 0.3971 - val_mean_absolute_error: 0.1325
# Epoch 5/50
# 800/800 [==============================] - 0s 129us/step - loss: 0.3542 - mean_absolute_error: 0.1201 - val_loss: 0.3199 - val_mean_absolute_error: 0.1165
# Epoch 6/50
# 800/800 [==============================] - 0s 204us/step - loss: 0.2956 - mean_absolute_error: 0.1091 - val_loss: 0.2836 - val_mean_absolute_error: 0.1108
# Epoch 7/50
# 800/800 [==============================] - 0s 169us/step - loss: 0.2624 - mean_absolute_error: 0.1059 - val_loss: 0.2401 - val_mean_absolute_error: 0.0861
# Epoch 8/50
# 800/800 [==============================] - 0s 128us/step - loss: 0.2394 - mean_absolute_error: 0.0954 - val_loss: 0.2307 - val_mean_absolute_error: 0.1073
# Epoch 9/50
# 800/800 [==============================] - 0s 125us/step - loss: 0.2214 - mean_absolute_error: 0.1018 - val_loss: 0.2128 - val_mean_absolute_error: 0.0875
# Epoch 10/50
# 800/800 [==============================] - 0s 112us/step - loss: 0.2068 - mean_absolute_error: 0.0849 - val_loss: 0.1960 - val_mean_absolute_error: 0.0877
# Epoch 11/50
# 800/800 [==============================] - 0s 117us/step - loss: 0.1968 - mean_absolute_error: 0.0911 - val_loss: 0.1956 - val_mean_absolute_error: 0.1041
# Epoch 12/50
# 800/800 [==============================] - 0s 119us/step - loss: 0.1870 - mean_absolute_error: 0.0887 - val_loss: 0.1787 - val_mean_absolute_error: 0.0724
# Epoch 13/50
# 800/800 [==============================] - 0s 119us/step - loss: 0.1822 - mean_absolute_error: 0.0796 - val_loss: 0.1760 - val_mean_absolute_error: 0.0853
# Epoch 14/50
# 800/800 [==============================] - 0s 106us/step - loss: 0.1781 - mean_absolute_error: 0.0892 - val_loss: 0.1749 - val_mean_absolute_error: 0.1111
# Epoch 15/50
# 800/800 [==============================] - 0s 104us/step - loss: 0.1805 - mean_absolute_error: 0.0992 - val_loss: 0.1695 - val_mean_absolute_error: 0.1199
# Epoch 16/50
# 800/800 [==============================] - 0s 101us/step - loss: 0.1662 - mean_absolute_error: 0.0822 - val_loss: 0.1596 - val_mean_absolute_error: 0.0654
# Epoch 17/50
# 800/800 [==============================] - 0s 106us/step - loss: 0.1615 - mean_absolute_error: 0.0823 - val_loss: 0.1888 - val_mean_absolute_error: 0.1339
# Epoch 18/50
# 800/800 [==============================] - 0s 100us/step - loss: 0.1596 - mean_absolute_error: 0.0848 - val_loss: 0.1611 - val_mean_absolute_error: 0.1219
# Epoch 19/50
# 800/800 [==============================] - 0s 134us/step - loss: 0.1574 - mean_absolute_error: 0.0861 - val_loss: 0.1537 - val_mean_absolute_error: 0.0906
# Epoch 20/50
# 800/800 [==============================] - 0s 98us/step - loss: 0.1533 - mean_absolute_error: 0.0835 - val_loss: 0.1494 - val_mean_absolute_error: 0.0971
# Epoch 21/50
# 800/800 [==============================] - 0s 124us/step - loss: 0.1505 - mean_absolute_error: 0.0788 - val_loss: 0.1418 - val_mean_absolute_error: 0.0602
# Epoch 22/50
# 800/800 [==============================] - 0s 125us/step - loss: 0.1460 - mean_absolute_error: 0.0756 - val_loss: 0.1442 - val_mean_absolute_error: 0.0733
# Epoch 23/50
# 800/800 [==============================] - 0s 111us/step - loss: 0.1474 - mean_absolute_error: 0.0789 - val_loss: 0.1583 - val_mean_absolute_error: 0.1471
# Epoch 24/50
# 800/800 [==============================] - 0s 103us/step - loss: 0.1501 - mean_absolute_error: 0.0958 - val_loss: 0.1401 - val_mean_absolute_error: 0.0893
# Epoch 25/50
# 800/800 [==============================] - 0s 93us/step - loss: 0.1433 - mean_absolute_error: 0.0861 - val_loss: 0.1442 - val_mean_absolute_error: 0.1088
# Epoch 26/50
# 800/800 [==============================] - 0s 128us/step - loss: 0.1419 - mean_absolute_error: 0.0836 - val_loss: 0.1400 - val_mean_absolute_error: 0.1021
# Epoch 27/50
# 800/800 [==============================] - 0s 119us/step - loss: 0.1394 - mean_absolute_error: 0.0810 - val_loss: 0.1343 - val_mean_absolute_error: 0.0839
# Epoch 28/50
# 800/800 [==============================] - 0s 139us/step - loss: 0.1323 - mean_absolute_error: 0.0660 - val_loss: 0.1325 - val_mean_absolute_error: 0.0872
# Epoch 29/50
# 800/800 [==============================] - 0s 103us/step - loss: 0.1329 - mean_absolute_error: 0.0643 - val_loss: 0.1291 - val_mean_absolute_error: 0.0650
# Epoch 30/50
# 800/800 [==============================] - 0s 110us/step - loss: 0.1328 - mean_absolute_error: 0.0697 - val_loss: 0.1277 - val_mean_absolute_error: 0.0608
# Epoch 31/50
# 800/800 [==============================] - 0s 112us/step - loss: 0.1330 - mean_absolute_error: 0.0779 - val_loss: 0.1249 - val_mean_absolute_error: 0.0721
# Epoch 32/50
# 800/800 [==============================] - 0s 114us/step - loss: 0.1347 - mean_absolute_error: 0.0927 - val_loss: 0.1261 - val_mean_absolute_error: 0.0804
# Epoch 33/50
# 800/800 [==============================] - 0s 115us/step - loss: 0.1318 - mean_absolute_error: 0.0859 - val_loss: 0.1267 - val_mean_absolute_error: 0.0683
# Epoch 34/50
# 800/800 [==============================] - 0s 104us/step - loss: 0.1268 - mean_absolute_error: 0.0734 - val_loss: 0.1271 - val_mean_absolute_error: 0.0749
# Epoch 35/50
# 800/800 [==============================] - 0s 112us/step - loss: 0.1258 - mean_absolute_error: 0.0766 - val_loss: 0.1276 - val_mean_absolute_error: 0.0775
# Epoch 36/50
# 800/800 [==============================] - 0s 97us/step - loss: 0.1266 - mean_absolute_error: 0.0760 - val_loss: 0.1170 - val_mean_absolute_error: 0.0473
# Epoch 37/50
# 800/800 [==============================] - 0s 126us/step - loss: 0.1236 - mean_absolute_error: 0.0673 - val_loss: 0.1186 - val_mean_absolute_error: 0.0678
# Epoch 38/50
# 800/800 [==============================] - 0s 93us/step - loss: 0.1199 - mean_absolute_error: 0.0646 - val_loss: 0.1252 - val_mean_absolute_error: 0.0852
# Epoch 39/50
# 800/800 [==============================] - 0s 93us/step - loss: 0.1197 - mean_absolute_error: 0.0648 - val_loss: 0.1219 - val_mean_absolute_error: 0.0702
# Epoch 40/50
# 800/800 [==============================] - 0s 103us/step - loss: 0.1223 - mean_absolute_error: 0.0825 - val_loss: 0.1176 - val_mean_absolute_error: 0.0762
# Epoch 41/50
# 800/800 [==============================] - 0s 86us/step - loss: 0.1192 - mean_absolute_error: 0.0760 - val_loss: 0.1225 - val_mean_absolute_error: 0.1067
# Epoch 42/50
# 800/800 [==============================] - 0s 116us/step - loss: 0.1171 - mean_absolute_error: 0.0665 - val_loss: 0.1145 - val_mean_absolute_error: 0.0611
# Epoch 43/50
# 800/800 [==============================] - 0s 111us/step - loss: 0.1174 - mean_absolute_error: 0.0753 - val_loss: 0.1182 - val_mean_absolute_error: 0.0791
# Epoch 44/50
# 800/800 [==============================] - 0s 106us/step - loss: 0.1161 - mean_absolute_error: 0.0711 - val_loss: 0.1114 - val_mean_absolute_error: 0.0602
# Epoch 45/50
# 800/800 [==============================] - 0s 115us/step - loss: 0.1167 - mean_absolute_error: 0.0741 - val_loss: 0.1154 - val_mean_absolute_error: 0.0775
# Epoch 46/50
# 800/800 [==============================] - 0s 105us/step - loss: 0.1155 - mean_absolute_error: 0.0814 - val_loss: 0.1101 - val_mean_absolute_error: 0.0592
# Epoch 47/50
# 800/800 [==============================] - 0s 113us/step - loss: 0.1140 - mean_absolute_error: 0.0760 - val_loss: 0.1145 - val_mean_absolute_error: 0.0924
# Epoch 48/50
# 800/800 [==============================] - 0s 113us/step - loss: 0.1120 - mean_absolute_error: 0.0673 - val_loss: 0.1128 - val_mean_absolute_error: 0.0820
# Epoch 49/50
# 800/800 [==============================] - 0s 127us/step - loss: 0.1128 - mean_absolute_error: 0.0710 - val_loss: 0.1068 - val_mean_absolute_error: 0.0548
# Epoch 50/50
# 800/800 [==============================] - 0s 119us/step - loss: 0.1137 - mean_absolute_error: 0.0779 - val_loss: 0.1081 - val_mean_absolute_error: 0.0628

# %%
best_model_idx = np.argmin(val_umae)
emu._model.load_weights("models/model_{:02d}.h5".format(best_model_idx))

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Mean Abs Error')
plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
       label='Train mae')
plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
       label = 'Val mae')
plt.legend()

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(history.epoch, np.array(history.history['loss']),
       label='Train Loss')
plt.plot(history.epoch, np.array(history.history['val_loss']),
       label = 'Val loss')
plt.legend()

# %%
plt.figure()
plt.xlabel('Epoch')
plt.ylabel('Unormalized mae')
plt.plot(history.epoch, val_umae)

# %% [markdown]
# # Likelihood metrics

# %%
emu_time = %timeit -r 50 -o emu(real_parameters)
print("Emulator prediction time (micro-seconds): {:5f}".format(emu_time.average * 1000000))
# Out:
# 479 µs ± 84.6 µs per loop (mean ± std. dev. of 50 runs, 1000 loops each)
# Emulator prediction time (micro-seconds): 479.414760

# %%
likelihood_time = %timeit -r 50 -o log_likelihood(real_parameters)
print("Likelihood prediction time (micro-seconds): {:5f}".format(likelihood_time.average * 1000000))
# Out:
# 33.5 µs ± 8.59 µs per loop (mean ± std. dev. of 50 runs, 10000 loops each)
# Likelihood prediction time (micro-seconds): 33.508342

# %%
pred_y = np.apply_along_axis(emu, 1, test_X)
print("Mean absolute error (mae): {:.5f}".format(emumet.mae(test_y, pred_y)))
# Out:
# Mean absolute error (mae): 91.40863

# %%
print("Mean percentage error (mape): {:.5f}".format(emumet.mape(test_y, pred_y) * 100))
# Out:
# Mean percentage error (mape): 8.64502

# %% [markdown]
# # Comparing MCMC run times

# %%
mcmc_method = pints.AdaptiveCovarianceMCMC

# MCMC parameters
num_chains = 3
max_iters = 10000

# %%
# Create a posterior log-likelihood (log(likelihood * prior))
emu_log_posterior = pints.LogPosterior(emu, log_prior)

# %%
xs = [
    found_parameters,
    found_parameters * 1.01,
    found_parameters * 0.99
]
xs
# Out:
# [array([1.49819079e-01, 4.99306274e+02]),
#  array([1.51317269e-01, 5.04299337e+02]),
#  array([1.48320888e-01, 4.94313212e+02])]

# %%
emu_mcmc = pints.MCMCSampling(emu_log_posterior,
                              num_chains,
                              xs,
                              method = mcmc_method,
                             )
emu_mcmc.set_log_to_screen(False)
print('Running...')
emu_chains = emu_mcmc.run()
print('Done!')
# Out:
# Running...
# Done!

# %%
real_mcmc = pints.MCMCSampling(log_posterior, 
                               num_chains, 
                               xs, 
                               method = mcmc_method,
                               )
real_mcmc.set_max_iterations(max_iters)
real_mcmc.set_log_to_screen(False)
# Run!
print('Running...')
real_chains = real_mcmc.run()
print('Done!')
# Out:
# Running...
# Done!

# %%
pints.plot.trace(emu_chains)
plt.show()

# %%
pints.plot.trace(real_chains)
plt.show()

# %% [markdown]
# # MCMC metrics

# %%
print('Emulator R-hat:')
print(pints.rhat_all_params(emu_chains))
# Out:
# Emulator R-hat:
# [0.9999700249897255, 1.0010499189195636]

# %%
print('Real R-hat:')
print(pints.rhat_all_params(real_chains))
# Out:
# Real R-hat:
# [1.0007813200076237, 1.0002806958617085]

# %%
# percentage
chain = real_chains[0]

chain_mape = emumet.chain_mape(chain, emu, log_likelihood)
print("Chain mean absolute percentage error: {:.5f}".format(chain_mape * 100))
# Out:
# Chain mean absolute percentage error: 0.60638

# %%
emu_mcmc_time = %timeit -o emu_mcmc.run()
print("Emulator MCMC time: {:.5f}".format(emu_mcmc_time.average))
# Out:
# 20 s ± 62.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Emulator MCMC time: 19.97803

# %%
real_mcmc_time = %timeit -o real_mcmc.run()
print("MCMC time: {:.5f}".format(real_mcmc_time.average))
# Out:
# 7.07 s ± 556 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# MCMC time: 7.07086

# %%
emu_parameters, emu_parameters_std = emumet.estimate_parameters(emu_chains)
print("Emulator estimated parameters: ", emu_parameters)
print("Emulator parametet std: ", emu_parameters_std)
# Out:
# Emulator estimated parameters:  [1.49561683e-01 4.97868225e+02]
# Emulator parametet std:  [8.83756221e-06 1.33628352e-02]

# %%
real_parameters, real_parameters_std = emumet.estimate_parameters(real_chains)
print("Estimated parameters: ", real_parameters)
print("parametet std: ", real_parameters_std)
# Out:
# Estimated parameters:  [1.49854152e-01 4.99286823e+02]
# parametet std:  [9.68200776e-06 3.09614573e-02]

# %% [markdown]
# # Plotting emulator surfaces around parameters

# %%
# use smaller bounds to get an idea of the surface around real parameters
min_bounds = np.min(chain, axis = 0)
max_bounds = np.max(chain, axis = 0)
bounds = pints.RectangularBoundaries(min_bounds, max_bounds)

# %%
bounds

# %%
# plot surfaces
if n_parameters >= 3:
    fixed_parameters = emutils.fix_parameters(bounds)
    
    fig, ax = emuplt.plot_fixed_param_grid(
        emu,
        fixed_parameters,
        bounds,
        shape = (n_parameters, n_parameters - 1),
        contour = False,
        index_to_param_name=index_to_param_name,
        additional_log_likelihoods = [log_likelihood]
    )

    plt.show(fig)
    
# for row i we have parameter i fixed and some other parameter j, depending on the column, j != i

# %%
print(bounds.lower())
print(bounds.upper())
# Out:
# [1.46675008e-01 4.87647087e+02]
# [1.53055948e-01 5.08070727e+02]

# %%
fig, ax = emuplt.plot_surface_fixed_param(
    emu,
    bounds,
    fixed = [(1, 0.29)],
    index_to_param_name=index_to_param_name,
    contour=False,
    precision=2,
    additional_log_likelihoods=[log_likelihood]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-da5a4b9ff597> in <module>
#       6     contour=False,
#       7     precision=2,
# ----> 8     additional_log_likelihoods=[log_likelihood]
#       9 )
#
# ~/Prog/emupints/emupints/plot.py in plot_surface_fixed_param(log_likelihood, bounds, fixed, n_splits, index_to_param_name, contour, additional_log_likelihoods, precision, **kwargs)
#     199     # get indices of params that are not fixed
#     200     if fixed:
# --> 201         p1_idx, p2_idx = [i for i in range(bounds.n_parameters())
#     202                           if i not in [j for (j, _) in fixed]]
#     203     else:
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
ax.view_init(30, 45 + 90 *3)
fig.set_size_inches(10.5, 6)
fig
